# %% [markdown]
# <a href="https://colab.research.google.com/github/vsjamwal/Algo-trading-Strategies-/blob/main/Predictive_analysis_shriram_AUM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **STOCK PRICE PREDICTION USING LINEAR REGRESSION**

# %% [markdown]
# Required Libraries

# %%
import yfinance as yf
import datetime
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# %%
# Define the stock symbols
symbols = ['LT.NS', 'RELIANCE.NS', 'SBIN.NS']

# Define the date range for the last 3 years
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=3 * 365)  # 3 years

# Create an empty DataFrame to store the closing prices
closing_prices_df = pd.DataFrame()

# %%
# Define the stock symbols
symbols = ['LT.NS', 'RELIANCE.NS', 'SBIN.NS']

# Define the date range for the last 3 years
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=3 * 365)  # 3 years

# Create an empty DataFrame to store the daily closing prices
closing_prices_df = pd.DataFrame()

# Fetch and append daily closing prices for each stock
for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    closing_prices_df[symbol] = stock_data['Close']

# Function to add a regression line and predict the next 5 days' values
def plot_stock_with_regression(symbol):
    plt.figure(figsize=(12, 6))

    # Extract the data
    x = np.arange(len(closing_prices_df.index))
    y = closing_prices_df[symbol]

    # Perform linear regression
    model = LinearRegression()
    model.fit(pd.DataFrame(x), y)
    regression_line = model.predict(pd.DataFrame(x))

    # Plot the data points and the regression line
    plt.plot(closing_prices_df.index, y, label=symbol)
    plt.plot(closing_prices_df.index, regression_line, label='Regression Line', linestyle='--')

    # Predict the next 5 days' values
    next_x = np.arange(len(closing_prices_df.index), len(closing_prices_df.index) + 5)
    next_y = model.predict(pd.DataFrame(next_x))

    # Display the predicted values in a table on the top left
    table_data = [[f'Day {i}', round(value, 2)] for i, value in enumerate(next_y, 1)]
    plt.table(cellText=table_data, loc='upper left', cellLoc='center')

    # Add labels, legends, and grid
    plt.title(f'Daily Closing Prices for {symbol}')
    plt.xlabel('Date')
    plt.ylabel('Price (INR)')
    plt.legend()
    plt.grid(True)

# Plot each stock with regression and predictions
for symbol in symbols:
    plot_stock_with_regression(symbol)
    plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Define the stock symbols
symbols = ['LT.NS', 'RELIANCE.NS', 'SBIN.NS']

# Define the date range for the last 3 years
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=3 * 365)  # 3 years

# Create an empty DataFrame to store the closing prices
closing_prices_df = pd.DataFrame()

# Fetch and append weekly closing prices for each stock
for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1wk')
    closing_prices_df[symbol] = stock_data['Close']

# Function to add a regression line and predict the next 5 weeks' values
def plot_stock_with_regression(symbol):
    plt.figure(figsize=(12, 6))

    # Extract the data
    x = range(len(closing_prices_df.index))
    y = closing_prices_df[symbol]

    # Perform linear regression
    model = LinearRegression()
    model.fit(pd.DataFrame(x), y)
    regression_line = model.predict(pd.DataFrame(x))

    # Plot the data points and the regression line
    plt.plot(closing_prices_df.index, y, label=symbol)
    plt.plot(closing_prices_df.index, regression_line, label='Regression Line', linestyle='--')

    # Predict the next 5 weeks' values
    next_x = range(len(closing_prices_df.index), len(closing_prices_df.index) + 5)
    next_y = model.predict(pd.DataFrame(next_x))

    # Display the predicted values in a table on the top left
    table_data = [[f'Week {i}', round(value, 2)] for i, value in enumerate(next_y, 1)]
    plt.table(cellText=table_data, loc='upper left', cellLoc='center')

    # Add labels, legends, and grid
    plt.title(f'Weekly Closing Prices for {symbol}')
    plt.xlabel('Week')
    plt.ylabel('Price (INR)')
    plt.legend()
    plt.grid(True)

# Plot each stock with regression and predictions
for symbol in symbols:
    plot_stock_with_regression(symbol)
    plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Define the stock symbols
symbols = ['LT.NS', 'RELIANCE.NS', 'SBIN.NS']

# Define the date range for the last 3 years
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=3 * 365)  # 3 years

# Create an empty DataFrame to store the monthly closing prices
closing_prices_df = pd.DataFrame()

# Fetch and append monthly closing prices for each stock
for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1mo')
    closing_prices_df[symbol] = stock_data['Close']

# Function to add a regression line and predict the next 5 months' values
def plot_stock_with_regression(symbol):
    plt.figure(figsize=(12, 6))

    # Extract the data
    x = np.arange(len(closing_prices_df.index))
    y = closing_prices_df[symbol]

    # Perform linear regression
    model = LinearRegression()
    model.fit(pd.DataFrame(x), y)
    regression_line = model.predict(pd.DataFrame(x))

    # Plot the data points and the regression line
    plt.plot(closing_prices_df.index, y, label=symbol)
    plt.plot(closing_prices_df.index, regression_line, label='Regression Line', linestyle='--')

    # Predict the next 5 months' values
    next_x = np.arange(len(closing_prices_df.index), len(closing_prices_df.index) + 5)
    next_y = model.predict(pd.DataFrame(next_x))

    # Display the predicted values in a table on the top left
    table_data = [[f'Month {i}', round(value, 2)] for i, value in enumerate(next_y, 1)]
    plt.table(cellText=table_data, loc='upper left', cellLoc='center')

    # Add labels, legends, and grid
    plt.title(f'Monthly Closing Prices for {symbol}')
    plt.xlabel('Month')
    plt.ylabel('Price (INR)')
    plt.legend()
    plt.grid(True)

# Plot each stock with regression and predictions
for symbol in symbols:
    plot_stock_with_regression(symbol)
    plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Other Matrices

# %%
import yfinance as yf
import datetime
import numpy as np
import pandas as pd

# Define the stock symbols
symbols = ['LT.NS', 'RELIANCE.NS', 'SBIN.NS']

# Define the date range for historic data (last 3 years)
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=3 * 365)

# Initialize dataframes to store daily closing prices
closing_prices = pd.DataFrame()

# Fetch daily closing prices for each stock
for symbol in symbols:
    data = yf.download(symbol, start=start_date, end=end_date)
    closing_prices[symbol] = data['Close']

# Calculate daily returns as percentages
returns = closing_prices.pct_change() * 100  # Convert to percentages

# Calculate the Sharpe Ratio for Buy and Hold Strategy
risk_free_rate = 0.065  # Assumed annual risk-free rate (e.g., government bond rate)

# Calculate expected return, volatility, and Sharpe Ratio for each stock
expected_return = returns.mean() * 252  # Annualize daily returns
volatility = returns.std() * np.sqrt(252)  # Annualize daily volatility
sharpe_ratio = (expected_return - risk_free_rate) / volatility

# Calculate "Expected Return for the Next Year" and "CAGR for the Last 3 Years"
beginning_prices = closing_prices.iloc[0]
ending_prices = closing_prices.iloc[-1]


# CAGR for the Last 3 Years
n = 3  # Number of years
cagr = ((ending_prices / beginning_prices) ** (1 / n) - 1) * 100

# Print the results
print("Sharpe Ratio for Buy and Hold Strategy:")
print(sharpe_ratio)
print("\nCAGR for the Last 3 Years (%):")
print(cagr)
print("\nVolatility (%):")
print(volatility)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Sharpe Ratio for Buy and Hold Strategy:
# LT.NS          1.855929
# RELIANCE.NS    0.208085
# SBIN.NS        1.428123
# dtype: float64
#
# CAGR for the Last 3 Years (%):
# LT.NS          51.483760
# RELIANCE.NS     2.112330
# SBIN.NS        44.025252
# dtype: float64
#
# Volatility (%):
# LT.NS          24.337721
# RELIANCE.NS    25.220324
# SBIN.NS        28.859445
# dtype: float64

# %%
# Fetch and append weekly closing prices for each stock
for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1wk')
    closing_prices_df[symbol] = stock_data['Close']

# Define the stock symbols
symbols = ['LT.NS', 'RELIANCE.NS', 'SBIN.NS']

# Define the date range for the last 3 years
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=3 * 365)  # 3 years

# Create an empty DataFrame to store the weekly closing prices
closing_prices_df = pd.DataFrame()

# Fetch and append weekly closing prices for each stock
for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1wk')
    closing_prices_df[symbol] = stock_data['Close']

# Calculate statistics
statistics = closing_prices_df.describe()

# Print statistics
print("Weekly Closing Price Statistics:")
print(statistics)

# Create tables for weekly closing prices
print("\nWeekly Closing Price Tables:")
for symbol in symbols:
    table = pd.DataFrame({'Date': closing_prices_df.index, 'Price (INR)': closing_prices_df[symbol]})
    print(f"\n{symbol}:\n{table}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Weekly Closing Price Statistics:
#              LT.NS  RELIANCE.NS     SBIN.NS
# count   157.000000   157.000000  157.000000
# mean   1851.730259  2356.557007  477.357962
# std     444.394182   231.804983  103.368472
# min     894.099976  1841.949951  189.250000
# 25%    1523.849976  2148.250000  428.899994
# 50%    1801.250000  2408.699951  502.149994
# 75%    2153.399902  2530.500000  560.849976
# max    3093.699951  2790.250000  616.500000
#
# Weekly Closing Price Tables:
#
# LT.NS:
#                  Date  Price (INR)
# Date
# 2020-10-12 2020-10-12   894.099976
# ...

# %%
# Define the date range for the last 5 years
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=5 * 365)  # 5 years

# Create an empty DataFrame to store the daily closing prices
closing_prices_df = pd.DataFrame()

# Fetch and append daily closing prices for each stock
for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    closing_prices_df[symbol] = stock_data['Close']

# Calculate daily returns
daily_returns_df = closing_prices_df.pct_change() * 100  # Convert to percentages

# Create a DataFrame for daily returns
daily_returns_df = daily_returns_df.reset_index()  # Add 'Date' as a column
daily_returns_df.rename(columns={"Date": "Date"}, inplace=True)

# Display the DataFrame
print("Daily Returns DataFrame (Last 5 years):")
daily_returns_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Daily Returns DataFrame (Last 5 years):
#            Date     LT.NS  RELIANCE.NS   SBIN.NS
# 0    2018-10-16       NaN          NaN       NaN
# 1    2018-10-17 -1.041114    -1.074073 -3.385126
# 2    2018-10-19 -0.482711    -4.342918 -0.019141
# 3    2018-10-22  0.045597    -3.509481 -0.287246
# 4    2018-10-23 -0.488979    -0.748131 -1.805267
# ...         ...       ...          ...       ...
# 1230 2023-10-09 -0.614151    -0.852028 -1.539760
# 1231 2023-10-10  0.042282     0.441636  1.119475
# 1232 2023-10-11  0.412872     1.587686 -0.557770
# 1233 2023-10-12 -0.225012     0.185491 -0.390922
# 1234 2023-10-13  0.254729    -0.004250 -1.689269
#
# [1235 rows x 4 columns]

# %%
pip install statsmodels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import yfinance as yf
import statsmodels.api as sm

# Define the stock symbols
symbols = ['LT.NS', 'RELIANCE.NS', 'SBIN.NS']

# Define the date range for the last 3 years
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=3 * 365)  # 3 years

# Create an empty DataFrame to store the monthly closing prices
closing_prices_df = pd.DataFrame()

# Fetch and append monthly closing prices for each stock
for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1mo')
    closing_prices_df[symbol] = stock_data['Close']

# Function to add a regression line and predict the next 5 months' values
def plot_stock_with_regression(symbol):
    plt.figure(figsize=(12, 6))

    # Extract the data
    x = np.arange(len(closing_prices_df.index))
    y = closing_prices_df[symbol]

    # Perform linear regression
    x = sm.add_constant(x)  # Add a constant for the intercept
    model = sm.OLS(y, x).fit()
    regression_line = model.predict(x)

    # Calculate R-squared value
    r_squared = model.rsquared

    # Calculate p-value for the regression coefficient
    p_value = model.pvalues[1]  # Assuming the first coefficient is for the independent variable

    # Plot the data points and the regression line
    plt.plot(closing_prices_df.index, y, label=symbol)
    plt.plot(closing_prices_df.index, regression_line, label='Regression Line', linestyle='--')

    # Predict the next 5 months' values
    next_x = np.arange(len(closing_prices_df.index), len(closing_prices_df.index) + 5)
    next_x = sm.add_constant(next_x)
    next_y = model.predict(next_x)

    # Display the predicted values in a table on the top left
    table_data = [[f'Month {i}', round(value, 2)] for i, value in enumerate(next_y, 1)]
    plt.table(cellText=table_data, loc='upper left', cellLoc='center')

    # Add labels, legends, and grid
    plt.title(f'Monthly Closing Prices for {symbol}')
    plt.xlabel('Month')
    plt.ylabel('Price (INR)')
    plt.legend()
    plt.grid(True)

    # Print regression statistics
    print(f"Regression Model for {symbol}:")
    print(f"R-squared: {r_squared}")
    print(f"P-value for the coefficient: {p_value}")
    print(model.summary())

# Plot each stock with regression and predictions
for symbol in symbols:
    plot_stock_with_regression(symbol)
    plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Regression Model for LT.NS:
# R-squared: 0.8467571832690459
# P-value for the coefficient: 2.0817679924576215e-15
#                             OLS Regression Results
# ...
# Dep. Variable:                  LT.NS   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     187.9
# Date:                Sun, 15 Oct 2023   Prob (F-statistic):           2.08e-15
# Time:                        17:50:44   Log-Likelihood:                -238.21
# No. Observations:                  36   AIC:                             480.4
# Df Residuals:                      34   BIC:                             483.6
# Df Model:                           1
# ...

# %% [markdown]
# Report on the Significance of Regression Models for Stock Closing Prices
#
# 1. LT.NS:
#    - R-squared: 0.847 (High)
#    - P-value for the coefficient: 2.08e-15 (Low)
#    - Conclusion: The regression model for LT.NS is highly significant, and the month is a strong predictor of its closing price.
#
# 2. RELIANCE.NS:
#    - R-squared: 0.380 (Moderate)
#    - P-value for the coefficient: 6.33e-05 (Low)
#    - Conclusion: The regression model for RELIANCE.NS is moderately significant, and the month is a statistically significant predictor of its closing price.
#
# 3. SBIN.NS:
#    - R-squared: 0.810 (High)
#    - P-value for the coefficient: 7.88e-14 (Low)
#    - Conclusion: The regression model for SBIN.NS is highly significant, and the month is a strong predictor of its closing price.
#
# In summary, the regression models for LT.NS and SBIN.NS are highly significant, indicating that the month is a strong predictor of their closing prices. The model for RELIANCE.NS is moderately significant, suggesting a moderate relationship between the month and its closing price.

# %% [markdown]
# # Predicting the significance of daily price linear regression model

# %%
from sklearn.linear_model import LinearRegression

# Function to assess the significance of the regression model
def assess_daily_price_prediction(symbol):
    # Extract the data
    x = np.arange(len(closing_prices_df.index))
    y = closing_prices_df[symbol]

    # Check for and handle NaN values
    if x.shape != y.shape:
        raise ValueError(f"Input data for {symbol} contains NaN values. Handle missing data before proceeding.")

    # Perform linear regression
    model = LinearRegression()
    model.fit(pd.DataFrame(x), y)

    # Calculate R-squared value
    r_squared = model.score(pd.DataFrame(x), y)

    # Print the results
    print(f"Regression Model for {symbol}:")
    print(f"R-squared: {r_squared}")

    # Assess the significance of the regression
    if r_squared >= 0.5:
        print("R-squared is high, indicating a significant relationship.")
    else:
        print("R-squared is low, indicating a weak relationship.")

# Remove rows with NaN values in the DataFrame
closing_prices_df = closing_prices_df.dropna()

# Assess significance for daily price predictions
for symbol in symbols:
    assess_daily_price_prediction(symbol)
# Out:
# Regression Model for LT.NS:
# R-squared: 0.8334459648711552
# R-squared is high, indicating a significant relationship.
# Regression Model for RELIANCE.NS:
# R-squared: 0.46085913565546355
# R-squared is low, indicating a weak relationship.
# Regression Model for SBIN.NS:
# R-squared: 0.7904650176533571
# R-squared is high, indicating a significant relationship.
